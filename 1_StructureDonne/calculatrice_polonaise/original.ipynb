# %% [markdown]
# # <center> Calculatrice polonaise </center>
#
# ### <center> <em> Un exemple d'utilisation de la notion de pile en informatique </em>

# %% [markdown]
# On donne ci-dessous un script Python qui permet de modéliser la structure de pile.

# %%
class Cellule :
    def __init__(self, contenu, suivante):
        self.contenu = contenu
        self.suivante = suivante

class Pile:
    def __init__(self):
        """Initialise la pile comme une pile vide."""
        self.data = None
    
    def est_vide(self):
        """Renvoie True si la liste est vide, False sinon."""
        return self.data == None
    
    def empile(self, x):
        """Ajoute l'élément x sur le sommet de la pile, ne renvoie rien."""
        self.data = Cellule(x, self.data)
    
    def depile(self):
        """Retire l’élément au sommet de la pile et le renvoie."""
        v = self.data.contenu           # on récupère la valeur à renvoyer
        self.data = self.data.suivante  # on supprime la 1ère cellule  
        return v
    
    def __str__(self):
        """Affiche les éléments de la pile"""
        s = ""
        c = self.data
        while c != None :
            s += "|\t" + str(c.contenu)+ "\t|" + "\n"
            c = c.suivante
        s = "\nEtat de la pile:\n" + s
        return s

# %% [markdown]
# **Dans tout ce TP, la manipulation des piles ne se fera qu'en utilisant les méthodes de cette classe `Pile`.**

# %% [markdown]
# **Activité 1 : (Opérations sur la pile)**
#
# Dans cet exercice, on travaille avec une pile formée d'entiers. Les questions suivantes sont indépendantes.
#
# 1. En partant d’une pile vide `p`, écrire la suite d'instructions qui modifie la pile `p` pour obtenir le contenu 5, 7, 2, 4, dans cet ordre, 5 étant le premier empilé et 4 le dernier, donc le sommet de la pile.
#
# Pour chacune des fonctions suivantes, la pile devra toujours retrouver son état initial.
# Une fois les scripts écrits, vous veillerez à supprimer les instructions `pass`.
#
# 2. Écrire une fonction `pile_contient` qui prend en paramètres une pile et un élément ; cette fonction teste si la pile contient cet élément en renvoyant `True` si l’élément est dans la pile, `False` sinon. Le code de la fonction devra faire appel à la fonction `depile`.
#
#
# 3. Écrire une fonction `calcule_somme` qui prend en paramètre une pile, calcule et renvoie la somme des éléments de la pile.
#
#
# 4. Écrire une fonction `avant_dernier` qui prend en paramètre une pile et renvoie l’avant-dernier élément de la pile s'il existe, `None` sinon).

# %%
# Question 1
 


# Question 2
def pile_contient(pile, element):
    """
    Paramètres
    ----------
    pile : (list)
      La pile dans laquelle on veut tester la présence d'un élément.
    element : (int ou str)
      L'élément dont on veut tester l'existence ou non dans la pile.
    
    Résultat
    --------
    un booléen égal à True si l'élément est dans la pile, False sinon. 
    """
    pass
        

# Question 3
def calcule_somme(pile):
    """ Cette fonction calcule la somme des éléments de la pile.
    Paramètre : pile (list)
    Sortie : un entier correspondant à la somme des éléments de la pile
    """
    pass

# Question 4 
def avant_dernier(pile):
    """ Cette fonction retourne l'avant-dernier élément de la pile.
    Paramètre : pile (list)
    Sortie : un entier correspondant à l'avant-dernier élément de la pile.
    """
    pass

# %% [markdown]
# 5. Proposer ci-dessous des jeux de tests pertinents permettant de valider le code des fonctions écrites aux questions 2, 3 et 4 de cette activité.
# On pensera notamment à tester les cas particuliers des piles de 0, 1 ou 2 élément(s).

# %%
# Jeu de tests pour la question 2




# Jeu de tests pour la question 3




# Jeu de tests pour la question 4

# %% [markdown]
# **Activité 2 : (gare de triage)**
#
# *Objectif : résoudre un problème de triage en modélisant une zone de stockage par une pile.*
#
# En suivant les instructions du chef de gare et en utilisant les opérations sur une pile, écrire la fonction `tri_wagons` qui sépare les wagons bleus et rouges d’un train.

# %%
def tri_wagons(train):
    """ Trie les wagons rouges/bleus d'un train
    Paramètre
    ---------
    train : (str) 
      une chaîne de caractères représentant un train avec des wagons bleus (nombre) et rouges (lettres).
    
    Résultat
    --------
    une chaîne de caractères représentant le nouveau train dans lequel les wagons sont triés avec les bleus d'abord et les 
    rouges ensuite. 
    """
    
    pass

# %%
assert tri_wagons("A 4 C 12") == "4 12 C A"
assert tri_wagons("K 8 P 17 L B R 3 10 2 N") == "8 17 3 10 2 N R B L P K"

# %% [markdown]
# **Exercice :**
#
# Calculer la valeur des expressions suivantes écrites en notation polonaise :
# * `13 5 + 3 *` : .............................................
#
# * `3 5 7 * +` : .............................................
#
# * `3 5 7 + *` : .............................................
#
# * `15 5 / 4 12 + *`: .............................................

# %% [markdown]
# **Activité 3 : (Calculatrice polonaise)**
#
# *Objectif : programmer une mini-calculatrice qui calcule les expressions en écriture polonaise.*
#
# 1. Écrire une fonction `operation` qui calcule la somme ou le produit de deux nombres `a` et `b`.
#
#
# 2. Ecrire une fonction `calculatrice_polonaise` qui correspond à l'implémentation, en Python, de l'algorithme écrit en langage naturel dans le document pdf.
#
#
# 3. Modifier le code pour prendre en charge la soustraction et la division.

# %%
#Question 1 

def operation(a, b, op):
    """ Calcule la valeur de 'a + b 'ou 'a * b' ...
    Paramètres
    ----------
    a, b : (int) 
      les opérandes
    op : (str) 
      un caractère correspondant à l'opérateur à appliquer aux nombres a et b. 
    
    Résultat
    --------
      le résultat de l'opération (int ou éventuellement float)"""
    
    pass


#Question 2
def calculatrice_polonaise(expression):
    """ Calcule la valeur d'une expression codée en notation polonaise
    Paramètre
    ---------
    expression : (str)
      une chaîne de caractères représentant une expression en notation polonaise.
    
    Résultat
    --------
      le résultat de l'opération (nombre entier ou flottant)."""
    
    pass

# %%
# Tests question 1
assert operation(2, 4, "+") == 6
assert operation(2, 4, "*") == 8
assert operation(8, 4, "/") == 2.0

# Tests question 2
assert calculatrice_polonaise("2 3 4 + +") == 9
assert calculatrice_polonaise("2 3 + 5 *") == 25
assert calculatrice_polonaise("8 7 3 + *") == 80
assert calculatrice_polonaise("8 7 3 * +") == 29
assert calculatrice_polonaise("3 5 * 2 + 7 * 3 8 1 - * +") == 140
assert calculatrice_polonaise("1 2 1 2 1 2 1 2 + * + * + * +") == 31
assert calculatrice_polonaise("6 1 5 1 4 1 3 1 2 1 - * - * - * - * -") == 3
assert calculatrice_polonaise("1 1 2 1 3 1 2 + / + / + /") == 0.5

# %% [markdown]
# **Activité 4 : expression bien parenthésée**
#
# *Objectif : déterminer si les parenthèses d'une expression sont placées de façon cohérente.*
#
# 1. Ecrire une fonction `parentheses_correctes` qui prend pour paramètre `expression`, une chaîne de caractères représentant une expression mathématique, et qui renvoie `True` si l'expression est bien parenthésée, `False` sinon.
#
#
# 2. Améliorer cette fonction en une autre fonction nommée `crochets_parentheses_correctes` pour tester une expression avec des parenthèses et des crochets.

# %%
def parentheses_correctes(expression):
    """
    Paramètre
    ---------
    expression : (str) 
      une expression mathématique en notation classique.
      
    Résultat
    --------
      un booléen égal à True si l'expression est bien parenthésée, False sinon."""
    
    pass
    
      
def crochets_parentheses_correctes(expression):
    """ 
    Paramètre
    ---------
    expression : (str) 
      une expression mathématique en notation classique.
      
    Résultat
    -------- 
      un booléen égal à True si les parenthèses et les crochets de l'expression sont cohérents, False sinon."""
    
    pass

# %%
# Tests question 1
assert parentheses_correctes("(2+3)*(4+(8/2))") == True
assert parentheses_correctes("(x+y)*((7+z)") == False
assert parentheses_correctes(")(x+y)*((7+z)") == False


# Tests question 2
expression = "(a+b)^2 = (a^2 + [b^2+[2(ab)]])"
assert crochets_parentheses_correctes(expression) == True

expression = "((a+b)]^3 = [a+b]"
assert crochets_parentheses_correctes(expression) == False

expression = "[a+b)^4] = (a+b)"
assert crochets_parentheses_correctes(expression) == False

assert not crochets_parentheses_correctes("(3*x+2)*7+3*(x-1")
assert crochets_parentheses_correctes("[[[3*x+1]*x+1]*x+1]*x+1")
assert crochets_parentheses_correctes("1/(1+1/(1+1/(1+x)))")

# %% [markdown]
# **Activité 5 : (Conversion en écriture polonaise)**
#
# *Objectif : transformer une expression algébrique classique avec parenthèses en une écriture polonaise. L’algorithme est une version très améliorée de l’activité précédente.*
#
# Ecrire une fonction `ecriture_polonaise` qui correspond à l'implémentation, en Python, de l'algorithme écrit en langage naturel dans le document pdf.

# %%
def ecriture_polonaise(expression):
    """ Convertit une expression en écriture habituelle en notation polonaise.
    Paramètre
    ---------
      expression : (str) 
        une expression mathématique écrite en notation classique, avec les éléments séparés par des espaces
    
    Résultat
    --------
      une chaîne de caractères correspondant à la notation de l'expression en notation polonaise
    """
    
    pass

# %%
assert ecriture_polonaise("2 + 3") == "2 3 +"
assert ecriture_polonaise("4 * ( 2 + 3 )") == "4 2 3 + *"
assert ecriture_polonaise("( 2 + 3 ) * ( 4 + 8 )") == "2 3 + 4 8 + *"
assert ecriture_polonaise("( 4 / 2 ) * ( 4 + 8 )") == "4 2 / 4 8 + *"
assert ecriture_polonaise("1 + 2 + ( 12 + 3 ) * 5") == "1 2 + 12 3 + 5 * +"
assert ecriture_polonaise("1 + 2 + 5 * ( 12 - 3 )") == "1 2 + 5 12 3 - * +"

# %% [markdown]
# **Exercice final :**
#
# Vérifier que tout fonctionne correctement sur l'exemple suivant :
#
# 1. Définir l'expression `exp = "( 17 * ( 2 + 3 ) ) + ( 4 + ( 8 * 5 ) )"`.
#
#
# 2. Demander à Python d'évaluer cette expression en saisissant l'instruction `eval(exp)`.
#
#
# 3. L’instruction `calculatrice_polonaise(ecriture_polonaise(exp))` doit renvoyer le même résultat.

# %% [markdown]
# 4. Tester sur d’autres expressions en veillant à faire intervenir les 4 opérateurs.
