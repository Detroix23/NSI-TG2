# %% [markdown]
# # <center> <b> Automatismes </b> </center>
# ## <center> <i> Tri par sélection </i> <center>
#
# On dispose du code incomplet d’une fonction `tri_selection` qui prend en paramètre une liste `tab` de nombres entiers et qui renvoie le tableau trié par ordre croissant. Elle utilise l’algorithme suivant :
# - on recherche le plus petit élément du tableau, et on l’échange avec l’élément d’indice 0 ;
# - on recherche le second plus petit élément du tableau, et on l’échange avec l’élément d’indice 1 ;
# - on continue de cette façon jusqu’à ce que le tableau soit entièrement trié.
#
# Complétez le code ci-dessous et enfin testez-le. Un exemple de test est donné sous la fonction.
#
# Cette fonction devra réussir, en particulier, le test suivant :

# %%
print(tri_selection([1, 52, 6, -9, 12]))
assert tri_selection([1, 52, 6, -9, 12]) == [-9, 1, 6, 12, 52]
# Out:
# [52, -9, 1, 6, 12]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# C:\Users\HECTOR~1.GAR\AppData\Local\Temp/ipykernel_260/2879511716.py in <module>
#       1 print(tri_selection([1, 52, 6, -9, 12]))
# ----> 2 assert tri_selection([1, 52, 6, -9, 12]) == [-9, 1, 6, 12, 52]
#
# AssertionError:

# %%
def tri_selection(tab : list)-> list:
    for i in range(len(tab)):
        i_min = 0
        for j in range(i, len(tab)):
            if tab[j] < tab[i_min]:
                i_min = j
        if i_min != i:
            tab[i_min], tab[i] = tab[i], tab[i_min]
    return tab
