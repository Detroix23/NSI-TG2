# %% [markdown]
# # <center> <b> Automatismes </b> <center>
# # <center> <i> Tri itératif </i> <center>
#
# On considère l'algorithme de tri de tableau suivant :
# à chaque étape, on parcourt, depuis le début du tableau, tous les éléments non rangés et on place en dernière position le plus grand élément.
#
# Exemple avec le tableau : `t = [41, 55, 21, 18, 12, 6, 25]`.
#
# * **Étape 1 :** on parcourt tous les éléments du tableau, on permute le plus grand élément avec le dernier.
#
# Le tableau devient `t = [41, 25, 21, 18, 12, 6, 55]`.
#
# * **Étape 2 :** on parcourt tous les éléments sauf le dernier, on permute le plus grand élément trouvé avec l'avant dernier.
#
# Le tableau devient : `t = [6, 25, 21, 18, 12, 41, 55]`.
#
# Et ainsi de suite.
#
# Le code incomplet de la fonction `tri_iteratif` qui implémente cet algorithme est donné ci-dessous.

# %%
def tri_iteratif(tab):
    for k in range(len(tab)-1, 0 , -1):
        imax = k
        for i in range(0, imax):
            if tab[i] > tab[imax] :
                imax = i
        
        tmp = tab[imax]
        tab[imax] = tab[k]
        tab[k] = tmp
    return tab

# %% [markdown]
# Compléter le code qui doit passer ce test :

# %%
assert tri_iteratif([41, 55, 21, 18, 12, 6, 25]) == [6, 12, 18, 21, 25, 41, 55]

# %% [markdown]
# Générer une liste d'entiers aléatoires et vérifier que l'appel à la fonction `tri_iteratif` renvoie le bon résultat.
# Exécuter plusieurs fois le script, en changeant la taille de la liste.

# %%
from random import randint
l = []
for _ in range (10):
    l.append(randint(0,100))
print (tri_iteratif(l))
