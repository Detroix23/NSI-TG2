# %% [markdown]
# # <center> <b> Automatismes </b> <center>
# # <center> <i> Sommes et dictionnaires </i> <center>
#
# On considère le tableau suivant dont les éléments sont des dictionnaires :

# %%
animaux = [ {'nom' : 'Medor', 'espece' : 'chien', 'age' : 5, 'enclos' : 2},
            {'nom' : 'Titine', 'espece' : 'chat', 'age' : 2, 'enclos' : 5},
            {'nom' : 'Tom', 'espece' : 'chat', 'age' : 7, 'enclos' : 4},
            {'nom' : 'Belle', 'espece' : 'chien', 'age' : 6, 'enclos' : 3},
            {'nom' : 'Mirza', 'espece' : 'chat', 'age' : 6, 'enclos' : 5}]

# %% [markdown]
# Écrire une fonction `moyenne` qui prend pour paramètre `liste`, une liste dont chaque élément est un dictionnaire contenant les données sur un animal, et  qui renvoie l'âge moyen des chats. Cette fonction devra réussir le test suivant :

# %%
assert moyenne(animaux) == 5.0

# %%
def moyenne(animaux):
    cpt_chats = 0
    somme_ages = 0
    for dico in animaux:
        if dico["espece"] == 'chat':
            somme_ages += dico["age"]
            cpt_chats += 1
    return a/cpt
