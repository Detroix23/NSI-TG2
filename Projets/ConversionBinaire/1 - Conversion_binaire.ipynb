# %% [markdown]
# # <center> <b> Automatismes </b> </center>
# # <center> <i> Conversion </i> </center>
#
# Pour rappel, la conversion d’un nombre entier positif en binaire peut s’effectuer à l’aide des divisions successives comme illustré ici :
#
# <center> <img src='conversion.png' width = '300' > </center>
#
# Voici une fonction Python basée sur la méthode des divisions successives permettant de convertir un nombre entier positif en binaire :

# %%
def binaire(a):
    bin_a = str(...)
    a = a // 2
    while a ... :
        bin_a = ...(a % 2) + ...
        a = ...
    return bin_a

# %% [markdown]
# Compléter la fonction `binaire` et proposer un jeu de tests en utilisant l'instruction native `assert`de Python.

# %%
# Jeu de tests

# %%
# Votre code ici
