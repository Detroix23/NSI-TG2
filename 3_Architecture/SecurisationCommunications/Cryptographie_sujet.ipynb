# %% [markdown]
# # <center> Cryptographie </center>
#
# ## I - Chiffrement de César

# %% [markdown]
# ### Question 1
# Déchiffrez, à la main, les messages suivants :
# * **EORTXHC DVWHULA** chiffré avec un décalage $k = 3$.
# * **YE OCD ZKXYBKWSH** chiffré avec un décalage $k = 10$.

# %% [markdown]
# **Vos réponses :**
# *
# *

# %% [markdown]
# ### Activité 1

# %%
Alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# %% [markdown]
# **Question 1**

# %%
def chiffre_cesar_caractere(car, k):
    """ Renvoie la lettre codée après décalage de k lettres """

    pass

# %%
# Si votre script est correct, l'exécution de cette cellule de code ne génèrera pas d'erreur. 
assert chiffre_cesar_caractere('A', 3) == 'D'
assert chiffre_cesar_caractere('Y', 3) == 'B'

# %% [markdown]
# **Question 2**

# %%
def chiffre_cesar_phrase(phrase, k):
    """" Chiffre une phrase par un décalage de k lettres """

    pass

# %%
# Si votre script est correct, l'exécution de cette cellule de code ne génèrera pas d'erreur. 
phrase = "CAPTUREZ IDEFIX !"
phrase_codee = chiffre_cesar_phrase(phrase, 3)
assert phrase_codee == "FDSWXUHC LGHILA !"

phrase = "BLOQUEZ ASTERIX"
phrase_codee = chiffre_cesar_phrase(phrase, 3)
assert phrase_codee == "EORTXHC DVWHULA"

phrase = "OU EST PANORAMIX"
phrase_codee = chiffre_cesar_phrase(phrase, 10)
assert phrase_codee == "YE OCD ZKXYBKWSH"

# %% [markdown]
# **Question 3**

# %%
def dechiffre_cesar_phrase(phrase,k):
    """" Déchiffre une phrase par un décalage de k lettres à rebours """   
     
    pass

# %%
# Si votre script est correct, l'exécution de cette cellule de code ne génèrera pas d'erreur. 
phrase_codee = "YE OCD ZKXYBKWSH"
assert dechiffre_cesar_phrase(phrase_codee, 10) == "OU EST PANORAMIX"

# %% [markdown]
# **Question 4**

# %%
def attaque_cesar(phrase):
    """ Affichage de toutes les possibilités """

    pass

# %% [markdown]
# **Question 5**

# %%
#Votre code ici

# %% [markdown]
# Clé du chiffrement :

# %% [markdown]
# ## II - Chiffrement par substitution

# %% [markdown]
# ### Exercice du cours 3
# Avec la substitution choisie dans le cours 3 :
# 1) chiffrez le message : **AU REVOIR**.
# 2) déchiffrez le message : **ywd cdiyq**.

# %% [markdown]
# **Vos réponses :**
# 1)
# 2)

# %% [markdown]
# ### Activité 2

# %%
Alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
Melange = "ykcodmfjgzaxrnbutqiphwesvl"

# Génération d'un mélange aléatoire
# Dé-commentez les instructions suivantes pour générer un autre mélange des lettres de l'alphabet.

# from random import *
# liste_lettres = list(Alphabet.lower())
# shuffle(liste_lettres)
# Melange = "".join(liste_lettres)

# %% [markdown]
# **Question 1**

# %%
def chiffre_substitution_caractere(car):
    """ Renvoie la lettre codée avec la substitution choisie """

    pass

# %%
# Tests
assert chiffre_substitution_caractere('A') == "y"
assert chiffre_substitution_caractere('V') == "w"

# %% [markdown]
# **Question 2**

# %%
def chiffre_substitution_phrase(phrase):
    """" Renvoie une phrase chiffrée par la méthode de substitution """

     pass

# %%
# Tests
phrase = "PAS DE POTION POUR OBELIX !"
assert chiffre_substitution_phrase(phrase) == "uyi od ubpgbn ubhq bkdxgs !"

phrase = "BONJOUR"
assert chiffre_substitution_phrase(phrase) == "kbnzbhq"

phrase = "AVE CESAR"
assert chiffre_substitution_phrase(phrase) == "ywd cdiyq"

# %% [markdown]
# **Question 3**

# %%
def dechiffre_substitution_caractere(car):
    """ Renvoie le déchiffrement d'un caractère préalablement codé avec la méthode de substitution """

    pass


def dechiffre_substitution_phrase(phrase):
    """" Renvoie le déchiffrement d'une phrase préalablement codée avec la méthode de substitution """

    pass

# %%
# Test
phrase_codee = "ywd cdiyq"
assert dechiffre_substitution_phrase(phrase_codee) == "AVE CESAR"

# %% [markdown]
# ## III - Attaque statistique
#
# ### Activité 3

# %%
Minuscules = "abcdefghijklmnopqrstuvwxyz"

# %% [markdown]
# **Question 1**

# %%
def substitution(phrase, Alphabet_depart, Alphabet_arrivee):
    """" Renvoie la phrase transformer par substitution """

    #A compléter
    
    pass

# %%
# Test
Alphabet_depart  = "abcdefghijklmnopqrstuvwxyz"
Alphabet_arrivee = "...S.....E..T............."
phrase_codee = "jdolwm jd mt vb ?"

assert substitution(phrase_codee, Alphabet_depart, Alphabet_arrivee) == "ES...T ES T. .. ?"

# %% [markdown]
# **Question 2**

# %%
def statistique(phrase):
    """ Renvoie un tableau dont chaque élément donne le nombre d'apparitions de la lettre, par ordre alphabétique """
    
    nb_occurrences = [0] * 26   # Initialisation du tableau des occurrences
    # A compléter
    
    pass

# %%
# Test
phrase = "jdolwm jd mt vb ?"
print(phrase)

statistique(phrase)

# %%
def affiche_statistiques(phrase):
    
    pass

# %%
# Test
phrase = "jdolwm jd mt vb ?"
print(phrase)

affiche_statistiques(phrase)

# %% [markdown]
# **Question 3**

# %%
def frequence(phrase):
    """ Fréquence de chaque lettre """
    
    pass

# %%
# Test 1
print("--- Fréquence d'apparition des lettres ---")
phrase = "jdolwm jd mt vb ?"
print(phrase)

freq = frequence(phrase)
print(freq)

# %%
# Test 2
print("--- Fréquence d'apparition des lettres ---")
phrase = "ESPRIT ES TU LA ?"
phrase = phrase.lower()
print(phrase)

freq = frequence(phrase)
print(freq)

# %%
def affiche_frequences(phrase):
    
    pass

# %%
# Test
print("--- Fréquence d'apparition des lettres ---")
phrase = "jdolwm jd mt vb ?"
print(phrase)
affiche_frequences(phrase)

# %%
# Test : vous pouvez bien sûr changer la phrase. 

phrase = "ET SI ON ESSAYAIT D ETRE HEUREUX"
phrase = phrase.lower()
print(phrase)

affiche_statistiques(phrase)
affiche_frequences(phrase)

# %%
# Test : vous pouvez bien sûr changer la phrase. 

phrase = "ET SI ON ESSAYAIT D ETRE HEUREUX"

Alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
Melange = "bzryjxscwqiveguopldmtanfhk"
phrase_codee = substitution(phrase,Alphabet,Melange)
print(phrase_codee)

affiche_statistiques(phrase_codee)
affiche_frequences(phrase_codee)

# %% [markdown]
# **Question 3**

# %%
# Les frères Goncourt
phrase_codee = "ay dmymndmnxlv vdm ay shvjnvhv fvd dznvgzvd ngvcyzmvd"

# %%
# Charles Darwin
phrase_codee = "apy pywpfpy tdv ydjsvspng np ybng woy apy pywpfpy apy wady lbjgpy nv apy wady vngpaavzpngpy movy fpaapy tdv y okowgpng ap mvpdc odc fionzpmpngy"

# %%
# Albert Einstein
phrase_codee = "kw yjnzfcn, i nmy lqwpx zp mwcy yzqy ny lqn fcnp pn azpiyczppn. kw ofwyclqn, i nmy lqwpx yzqy azpiyczppn ny lqn onfmzppn pn mwcy ozqflqzc. cic, pzqm wszpm fnqpc yjnzfcn ny ofwyclqn : fcnp pn azpiyczppn ny onfmzppn pn mwcy ozqflqzc !"

# %% [markdown]
# ## IV - Chiffrement de Vigenère
#
# ### Exercice du cours 5
#
# 1) Chiffrez, à la main, la phrase **UNE PRINCESSE GEEK** avec le chiffrement de Vigenère et la clé [4, 2, 3].
# 2) Déchiffrez, à la main, la phrase **QKOSW HX VLRVLR**, chiffrée avec la clé [4,2,3].

# %% [markdown]
# **Vos réponses :**
# 1)
# 2)

# %% [markdown]
# ### Activité 4

# %%
Alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"

# %% [markdown]
# **Question 1**

# %%
def chiffre_vigenere(phrase,cle):
    """" Renvoie la phrase chiffrée par un décalage de Vigenère """

    phrase_codee = ""
    # A compléter
    
    return phrase_codee

# %%
# Tests 
phrase = "AAA ABC"
assert chiffre_vigenere(phrase, [1, 2, 3]) == "BCD BDF"

phrase = "IL ETAIT UNE FOIS"
assert chiffre_vigenere(phrase, [4, 2, 3]) == "MN HXCLX WQI HRMU"

phrase = "MILOU ET TINTIN"
assert chiffre_vigenere(phrase, [4, 2, 3]) == "QKOSW HX VLRVLR"

# %% [markdown]
# **Question 2**

# %%
phrase1 = "dgeukvldeakkwwwdiwflalehvm"
affiche_frequences(phrase1)

#A compléter
